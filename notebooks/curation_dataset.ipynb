# %% [markdown]
# # Dataset curation for time series
#
# [![Open In Colab <](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ShawnHymel/377f33c96876c4c7201083ed4da3c76a/raw/4678b2b5b391d2e08b455394e6e1e4c669a797bf/time_series_dataset_curation.ipynb)
#
# In the paper "Efficient BackProp" [1], LeCun et al. shows that we can achieve a more accurate model (e.g. artificial neural network) in less time by standarizing (i.e. to a mean of 0 and unit variance) and decorrelating our input data.
#
# However, the process of standarization assumes that the data is normally distributed (i.e. Gaussian). If our data does not follow a Gaussian distribution, we should perform normalization [2], where we divide by the range to produce a set of values between 0 and 1.
#
# Create a directory */content/dataset* and upload your entire dataset there. Run through the cells in this notebook, following all of the directions to analyze the data and create a curated dataset. Note that we perform only standardization in this notebook.
#
# The standardized data will be stored in the */content/out* directory and zipped to */content/out.zip* for easy downloading.
#
# Author: EdgeImpulse, Inc.<br>
# Date: July 28, 2022<br>
# License: Apache-2.0<br>
#
# [1] http://yann.lecun.com/exdb/publis/pdf/lecun-98b.pdf
#
# [2] https://becominghuman.ai/what-does-feature-scaling-mean-when-to-normalize-data-and-when-to-standardize-data-c3de654405ed

# %% [markdown]
# ## Step 1: Read data from CSV files
#
# Read each CSV, verify that the data (and header) are valid, save the data in Numpy format, and save the associated filename in a list.

# %%
import csv
import os
import shutil
import random

import numpy as np
import matplotlib.pyplot as plt
import json

# %%
### Settings

# Path information
HOME_PATH = "/Users/moon/work/dotyklab/dotykGesture/gestures/notebooks"              # Location of the working directory
DATASET_PATH = "../DMP_9D_ACCEL_Logs/cleaned_new/dataset"   # Upload your .csv samples to this directory
OUT_PATH = "./out"           # Where output files go (will be deleted and recreated)
TRAIN_DIR = "training"              # Where to store training output files
TEST_DIR = "testing"                # Where to store testing output files
OUT_ZIP = "./out.zip"        # Where to store the zipped output files

# Set aside 20% for test
TEST_RATIO = 0.2

# Seed for pseudorandomness 
SEED = 42

# %%
### Read in .csv files to construct our data in a numpy array

X_all = []
filenames = []
first_sample = True
channel_names = None
sample_shape = 500

files = os.listdir(DATASET_PATH)
files = [x for x in files if '.csv' in x]

# Loop through all files in our dataset
for filename in files:
  print(filename)
  # Check if the path is a file
  filepath = os.path.join(DATASET_PATH, filename)
  if not os.path.isfile(filepath):
    continue

  # Read CSV file
  data = np.genfromtxt(filepath, 
                      dtype=float,
                      delimiter=',',
                      names=True)
    
  # Get length of the sample
  num_readings = 500#data.shape[0]

  # Extract sample rate (in milliseconds), header (without timestamp), and shape info (without 
  # timestamp) from the first sample we read
  if first_sample:
    channel_names = data.dtype.names
    first_sample = False
    sample_shape = (num_readings, len(channel_names))


  # Check to make sure the new sample conforms to the first sample
  else:

    # Check header
    if data.dtype.names != channel_names:
      print("Header does not match. Skipping", filename)
      continue

    # Check shape
    if (num_readings, len(channel_names)) != sample_shape:
      print("Shape does not match. Skipping", filename)
      continue

  # Create sample (drop timestamp column)
  sample = np.zeros(sample_shape)
  for i in range(num_readings):
    sample[i, :] = np.array(data[i].item())

  # Append to our dataset
  X_all.append(sample)

  # Append the filename to our list of filenames
  filenames.append(filename)

# Convert the dataset into a numpy array
X_all = np.array(X_all)

# Get number of samples and channels
num_samples = X_all.shape[0]
num_channels = len(channel_names)

print("Header:", channel_names)
print("Dataset shape:", X_all.shape)
print("Number of samples:", num_samples)
print("Number of files", len(filenames))
# Out:
# non_exersice.3b46d7ee.csv
# curl.3.csv
# non_exersice.b65d344b.csv
# non_exersice.4a87c651.csv
# non_exersice.ea59bca1.csv
# non_exersice.d53df1a6.csv
# shoulder_press.119.csv
# front_raise.153.csv
# dumbell_row.79.csv
# shoulder_press.125.csv
# dumbell_row.51.csv
# non_exersice.f875d480.csv
# non_exersice.4a3d60e9.csv
# dumbell_row.45.csv
# non_exersice.49e2f863.csv
# non_exersice.1b669352.csv
# non_exersice.250699d4.csv
# shoulder_press.131.csv
# non_exersice.71bd9a0b.csv
# non_exersice.bc360056.csv
# hammer_curl.22.csv
# non_exersice.ef17b5ec.csv
# non_exersice.27cdbba9.csv
# non_exersice.a0445c3f.csv
# non_exersice.74238d59.csv
# non_exersice.676da980.csv
# non_exersice.068c929c.csv
# non_exersice.4e10cd68.csv
# front_raise.53.csv
# non_exersice.69c0cce2.csv
# front_raise.47.csv
# shoulder_press.71.csv
# curl.71.csv
# front_raise.90.csv
# front_raise.84.csv
# curl.65.csv
# curl.136.csv
# curl.59.csv
# curl.122.csv
# curl.58.csv
# curl.137.csv
# non_exersice.3927599e.csv
# curl.64.csv
# front_raise.85.csv
# front_raise.91.csv
# curl.70.csv
# non_exersice.b634b10d.csv
# non_exersice.eecf9ae9.csv
# front_raise.52.csv
# non_exersice.fec7f2b0.csv
# non_exersice.61e0c246.csv
# non_exersice.35f2e456.csv
# non_exersice.9365bb36.csv
# non_exersice.2ce6452f.csv
# non_exersice.7d20746a.csv
# non_exersice.13eae8de.csv
# non_exersice.9cb5c251.csv
# non_exersice.694187d9.csv
# front_raise.185.csv
# hammer_curl.37.csv
# non_exersice.b3643746.csv
# shoulder_press.130.csv
# shoulder_press.124.csv
# front_raise.146.csv
# shoulder_press.118.csv
# non_exersice.d9992c03.csv
# non_exersice.77599684.csv
# curl.2.csv
# non_exersice.10c72626.csv
# non_exersice.cf5afa90.csv
# curl.0.csv
# non_exersice.b873a064.csv
# front_raise.144.csv
# shoulder_press.132.csv
# front_raise.178.csv
# dumbell_row.46.csv
# dumbell_row.52.csv
# non_exersice.91a95d2e.csv
# shoulder_press.126.csv
# hammer_curl.35.csv
# dumbell_row.85.csv
# non_exersice.a7aca9f3.csv
# non_exersice.cb697157.csv
# non_exersice.c44b510f.csv
# non_exersice.40d1237e.csv
# non_exersice.95ffd082.csv
# non_exersice.5d918478.csv
# front_raise.44.csv
# non_exersice.413a9b45.csv
# front_raise.50.csv
# front_raise.78.csv
# curl.99.csv
# shoulder_press.66.csv
# non_exersice.21f5a93c.csv
# front_raise.87.csv
# curl.66.csv
# non_exersice.9a5fc009.csv
# shoulder_press.99.csv
# curl.109.csv
# front_raise.93.csv
# curl.121.csv
# curl.135.csv
# curl.134.csv
# curl.120.csv
# front_raise.92.csv
# non_exersice.e2640923.csv
# curl.108.csv
# curl.73.csv
# curl.67.csv
# front_raise.86.csv
# shoulder_press.98.csv
# shoulder_press.73.csv
# curl.98.csv
# front_raise.79.csv
# shoulder_press.67.csv
# front_raise.51.csv
# front_raise.45.csv
# non_exersice.86e288aa.csv
# non_exersice.8c2bb2da.csv
# non_exersice.7af33f03.csv
# non_exersice.4b06b7d9.csv
# non_exersice.7c208f0f.csv
# non_exersice.808a45fc.csv
# hammer_curl.34.csv
# hammer_curl.20.csv
# dumbell_row.53.csv
# shoulder_press.127.csv
# shoulder_press.133.csv
# dumbell_row.47.csv
# front_raise.179.csv
# front_raise.145.csv
# non_exersice.d0b15e85.csv
# non_exersice.a548f5ea.csv
# non_exersice.5680a253.csv
# non_exersice.3ab928db.csv
# non_exersice.654c502a.csv
# non_exersice.a2010265.csv
# non_exersice.15e52fc0.csv
# non_exersice.55d20589.csv
# non_exersice.13cc9f8a.csv
# dumbell_row.43.csv
# non_exersice.7c19f8dc.csv
# shoulder_press.137.csv
# shoulder_press.123.csv
# dumbell_row.57.csv
# front_raise.141.csv
# non_exersice.d112c9d6.csv
# front_raise.155.csv
# hammer_curl.18.csv
# non_exersice.442edd12.csv
# non_exersice.4dc2960a.csv
# hammer_curl.24.csv
# front_raise.182.csv
# non_exersice.c845e33c.csv
# hammer_curl.30.csv
# non_exersice.e1c6865b.csv
# non_exersice.189d98b7.csv
# shoulder_press.63.csv
# curl.88.csv
# front_raise.69.csv
# front_raise.41.csv
# front_raise.55.csv
# curl.124.csv
# curl.130.csv
# non_exersice.0c24ca0e.csv
# front_raise.82.csv
# curl.118.csv
# curl.77.csv
# front_raise.96.csv
# shoulder_press.88.csv
# front_raise.97.csv
# curl.76.csv
# non_exersice.3439c74e.csv
# curl.119.csv
# front_raise.83.csv
# curl.131.csv
# curl.125.csv
# front_raise.54.csv
# non_exersice.b2c1d29d.csv
# front_raise.40.csv
# front_raise.68.csv
# non_exersice.5eea4d2f.csv
# curl.89.csv
# shoulder_press.62.csv
# non_exersice.9eec97a4.csv
# non_exersice.bb259c53.csv
# non_exersice.f89d3a6b.csv
# non_exersice.7bf6aaa4.csv
# non_exersice.33ed362b.csv
# non_exersice.afdb848f.csv
# non_exersice.deef2da3.csv
# non_exersice.953b8f22.csv
# non_exersice.03d25021.csv
# non_exersice.010baae5.csv
# non_exersice.06c94f1f.csv
# hammer_curl.31.csv
# front_raise.183.csv
# hammer_curl.25.csv
# non_exersice.fbd541bd.csv
# non_exersice.a88b42bc.csv
# hammer_curl.19.csv
# non_exersice.ea22458d.csv
# shoulder_press.122.csv
# front_raise.168.csv
# dumbell_row.56.csv
# dumbell_row.42.csv
# shoulder_press.136.csv
# non_exersice.f087b1ed.csv
# non_exersice.4754eeb9.csv
# non_exersice.1ad9368c.csv
# non_exersice.13665753.csv
# non_exersice.22ebb40e.csv
# non_exersice.00681506.csv
# curl.4.csv
# curl.6.csv
# non_exersice.4390338d.csv
# non_exersice.d03a8389.csv
# non_exersice.00c64cdb.csv
# hammer_curl.149.csv
# non_exersice.d3489f46.csv
# non_exersice.560e3cfd.csv
# shoulder_press.120.csv
# non_exersice.b2cb2f0e.csv
# shoulder_press.134.csv
# non_exersice.9fbf05ef.csv
# front_raise.156.csv
# shoulder_press.108.csv
# non_exersice.76bb82b2.csv
# front_raise.142.csv
# non_exersice.549d800e.csv
# non_exersice.d388cbbc.csv
# non_exersice.15aacc48.csv
# hammer_curl.33.csv
# hammer_curl.8.csv
# hammer_curl.27.csv
# non_exersice.4bece0c8.csv
# non_exersice.16f862e0.csv
# non_exersice.ad258fc3.csv
# non_exersice.6ddccd30.csv
# shoulder_press.74.csv
# shoulder_press.60.csv
# shoulder_press.48.csv
# front_raise.56.csv
# non_exersice.1f3ccfb3.csv
# front_raise.42.csv
# non_exersice.6c821295.csv
# curl.133.csv
# curl.127.csv
# curl.74.csv
# front_raise.95.csv
# front_raise.81.csv
# curl.60.csv
# curl.61.csv
# front_raise.94.csv
# curl.75.csv
# curl.126.csv
# non_exersice.64f61eb2.csv
# curl.132.csv
# non_exersice.40d1f11c.csv
# front_raise.43.csv
# shoulder_press.49.csv
# non_exersice.ec57d80e.csv
# shoulder_press.61.csv
# shoulder_press.75.csv
# non_exersice.1fe19108.csv
# non_exersice.d8d2c568.csv
# hammer_curl.26.csv
# front_raise.180.csv
# hammer_curl.9.csv
# hammer_curl.32.csv
# non_exersice.688dc274.csv
# non_exersice.db03dce1.csv
# dumbell_row.96.csv
# shoulder_press.109.csv
# front_raise.157.csv
# dumbell_row.69.csv
# non_exersice.35faa873.csv
# shoulder_press.135.csv
# dumbell_row.41.csv
# hammer_curl.148.csv
# dumbell_row.55.csv
# shoulder_press.121.csv
# non_exersice.c207415d.csv
# non_exersice.e7960013.csv
# non_exersice.684cdf30.csv
# curl.7.csv
# non_exersice.e07bc7d7.csv
# dumbell_row.103.csv
# dumbell_row.117.csv
# hammer_curl.96.csv
# non_exersice.b532e093.csv
# non_exersice.87a268b6.csv
# hammer_curl.82.csv
# front_raise.124.csv
# hammer_curl.107.csv
# dumbell_row.32.csv
# shoulder_press.146.csv
# front_raise.118.csv
# non_exersice.39a2c901.csv
# non_exersice.46c0a040.csv
# dumbell_row.5.csv
# non_exersice.46d35d59.csv
# front_raise.24.csv
# front_raise.18.csv
# curl.12.csv
# non_exersice.ace3159a.csv
# non_exersice.0f7c2877.csv
# curl.141.csv
# curl.140.csv
# shoulder_press.13.csv
# front_raise.25.csv
# non_exersice.d7a76f98.csv
# non_exersice.7c44d665.csv
# front_raise.31.csv
# non_exersice.48b17fb7.csv
# non_exersice.319c9706.csv
# dumbell_row.4.csv
# non_exersice.c1004550.csv
# non_exersice.5140a225.csv
# non_exersice.4bacbc36.csv
# non_exersice.c6815441.csv
# non_exersice.baec9afc.csv
# hammer_curl.40.csv
# hammer_curl.54.csv
# non_exersice.29170653.csv
# dumbell_row.27.csv
# front_raise.119.csv
# dumbell_row.33.csv
# hammer_curl.83.csv
# non_exersice.87e7a04f.csv
# hammer_curl.112.csv
# front_raise.131.csv
# hammer_curl.97.csv
# non_exersice.db1da0fe.csv
# dumbell_row.116.csv
# non_exersice.a52d25ab.csv
# dumbell_row.114.csv
# dumbell_row.100.csv
# non_exersice.f1bf60f5.csv
# non_exersice.0facc097.csv
# front_raise.127.csv
# dumbell_row.19.csv
# hammer_curl.104.csv
# front_raise.133.csv
# hammer_curl.110.csv
# dumbell_row.25.csv
# hammer_curl.138.csv
# non_exersice.6866db27.csv
# shoulder_press.145.csv
# dumbell_row.31.csv
# hammer_curl.42.csv
# non_exersice.45a5f587.csv
# non_exersice.46a344b4.csv
# non_exersice.7dadf57f.csv
# dumbell_row.6.csv
# non_exersice.8229c878.csv
# non_exersice.c20e36f6.csv
# shoulder_press.39.csv
# front_raise.27.csv
# non_exersice.b1552dbb.csv
# shoulder_press.11.csv
# curl.11.csv
# non_exersice.41273734.csv
# non_exersice.feb5bae9.csv
# curl.39.csv
# curl.142.csv
# non_exersice.08b9e6c3.csv
# non_exersice.a814a401.csv
# curl.143.csv
# non_exersice.400228df.csv
# non_exersice.563a6e2b.csv
# non_exersice.ee9913d3.csv
# shoulder_press.10.csv
# front_raise.32.csv
# shoulder_press.38.csv
# front_raise.26.csv
# non_exersice.effd1c88.csv
# non_exersice.546777fe.csv
# non_exersice.6c15637a.csv
# non_exersice.ea4bb7eb.csv
# non_exersice.20963b50.csv
# non_exersice.54f5918d.csv
# hammer_curl.43.csv
# shoulder_press.144.csv
# non_exersice.13f38b5f.csv
# shoulder_press.9.csv
# dumbell_row.30.csv
# hammer_curl.139.csv
# dumbell_row.24.csv
# non_exersice.0d11a2b5.csv
# hammer_curl.94.csv
# front_raise.132.csv
# hammer_curl.105.csv
# non_exersice.7c2e2cbc.csv
# dumbell_row.18.csv
# hammer_curl.80.csv
# non_exersice.b2adc2a2.csv
# non_exersice.3d1a2ed9.csv
# non_exersice.e5661a7e.csv
# non_exersice.2a311e7d.csv
# dumbell_row.115.csv
# non_exersice.313b2124.csv
# non_exersice.f7f950e3.csv
# dumbell_row.111.csv
# dumbell_row.105.csv
# non_exersice.671818f4.csv
# non_exersice.f8094d2c.csv
# non_exersice.2ece947e.csv
# non_exersice.eb121c21.csv
# non_exersice.3c98257e.csv
# dumbell_row.34.csv
# hammer_curl.129.csv
# shoulder_press.140.csv
# front_raise.122.csv
# hammer_curl.101.csv
# front_raise.136.csv
# hammer_curl.90.csv
# hammer_curl.115.csv
# hammer_curl.47.csv
# hammer_curl.53.csv
# non_exersice.da167790.csv
# non_exersice.eeb14d1a.csv
# non_exersice.ea914d7e.csv
# non_exersice.41cdfd75.csv
# non_exersice.1998c0da.csv
# non_exersice.4033b3d2.csv
# dumbell_row.3.csv
# non_exersice.8b52ffb8.csv
# non_exersice.e63729c4.csv
# shoulder_press.14.csv
# front_raise.22.csv
# front_raise.36.csv
# non_exersice.11e6ad87.csv
# curl.147.csv
# non_exersice.50826a5c.csv
# curl.28.csv
# non_exersice.211492ea.csv
# curl.14.csv
# non_exersice.28f996f4.csv
# non_exersice.af87cccc.csv
# non_exersice.ad20eed6.csv
# non_exersice.30c2d89f.csv
# curl.29.csv
# curl.146.csv
# shoulder_press.29.csv
# front_raise.37.csv
# front_raise.23.csv
# shoulder_press.15.csv
# dumbell_row.2.csv
# non_exersice.86f64df0.csv
# non_exersice.7d6ca779.csv
# hammer_curl.46.csv
# non_exersice.ad9fa5b2.csv
# non_exersice.baa476bb.csv
# hammer_curl.114.csv
# front_raise.137.csv
# hammer_curl.100.csv
# hammer_curl.85.csv
# front_raise.123.csv
# hammer_curl.128.csv
# non_exersice.7249eadb.csv
# dumbell_row.35.csv
# shoulder_press.141.csv
# dumbell_row.21.csv
# non_exersice.77075c74.csv
# non_exersice.4e8b53cf.csv
# non_exersice.666e9d20.csv
# dumbell_row.104.csv
# dumbell_row.110.csv
# dumbell_row.106.csv
# dumbell_row.112.csv
# front_raise.9.csv
# shoulder_press.143.csv
# front_raise.109.csv
# dumbell_row.23.csv
# non_exersice.fe442311.csv
# hammer_curl.93.csv
# front_raise.121.csv
# hammer_curl.102.csv
# hammer_curl.78.csv
# non_exersice.6a1f85c6.csv
# non_exersice.7bf608c4.csv
# hammer_curl.44.csv
# non_exersice.53e626a9.csv
# non_exersice.0f3230e2.csv
# non_exersice.23a66e8c.csv
# non_exersice.460bbb51.csv
# shoulder_press.17.csv
# non_exersice.176d7677.csv
# non_exersice.05ededcb.csv
# curl.150.csv
# non_exersice.dd0c9c15.csv
# curl.144.csv
# non_exersice.0d758586.csv
# curl.17.csv
# non_exersice.67a51425.csv
# non_exersice.208c1621.csv
# curl.16.csv
# curl.145.csv
# non_exersice.0731bee5.csv
# front_raise.20.csv
# front_raise.34.csv
# non_exersice.e295c66a.csv
# shoulder_press.16.csv
# dumbell_row.1.csv
# non_exersice.dc2e6ba8.csv
# non_exersice.7b329bd0.csv
# non_exersice.587ed7be.csv
# non_exersice.cc6c1bc9.csv
# non_exersice.5caa3f85.csv
# non_exersice.039c7b4f.csv
# non_exersice.bb6044b6.csv
# hammer_curl.51.csv
# hammer_curl.79.csv
# front_raise.120.csv
# non_exersice.b9519d49.csv
# non_exersice.510d4f80.csv
# front_raise.134.csv
# hammer_curl.92.csv
# shoulder_press.142.csv
# dumbell_row.36.csv
# front_raise.8.csv
# non_exersice.c4ab7b92.csv
# non_exersice.6dc51422.csv
# dumbell_row.113.csv
# non_exersice.f5d56f1f.csv
# non_exersice.c4abfd04.csv
# non_exersice.a8a69d83.csv
# non_exersice.5aaac0ac.csv
# non_exersice.e495d3fa.csv
# non_exersice.ab31f705.csv
# non_exersice.8e19e50f.csv
# non_exersice.4d6f33b9.csv
# non_exersice.c20e63c8.csv
# non_exersice.e56e7c52.csv
# front_raise.105.csv
# hammer_curl.126.csv
# shoulder_press.2.csv
# dumbell_row.13.csv
# non_exersice.2bedf0e9.csv
# non_exersice.6feb7db1.csv
# non_exersice.014416db.csv
# hammer_curl.60.csv
# hammer_curl.48.csv
# non_exersice.1293b637.csv
# non_exersice.58728a99.csv
# non_exersice.bdbb4cf8.csv
# non_exersice.ac3ae25d.csv
# non_exersice.a435caec.csv
# non_exersice.05d7d8da.csv
# front_raise.11.csv
# shoulder_press.33.csv
# front_raise.39.csv
# non_exersice.150650d9.csv
# shoulder_press.27.csv
# non_exersice.67d3ad26.csv
# non_exersice.98848e96.csv
# curl.33.csv
# curl.148.csv
# non_exersice.b24c90b8.csv
# non_exersice.aa817dbe.csv
# curl.27.csv
# non_exersice.d8e3ef53.csv
# non_exersice.25e1b331.csv
# non_exersice.5d2ac35e.csv
# curl.26.csv
# curl.149.csv
# curl.32.csv
# front_raise.38.csv
# shoulder_press.26.csv
# non_exersice.68b72369.csv
# front_raise.10.csv
# non_exersice.6afaf5a7.csv
# non_exersice.20274945.csv
# hammer_curl.49.csv
# hammer_curl.75.csv
# non_exersice.89de5a76.csv
# front_raise.138.csv
# non_exersice.ff0247fc.csv
# non_exersice.f359542d.csv
# shoulder_press.3.csv
# hammer_curl.127.csv
# front_raise.110.csv
# non_exersice.a05e61a0.csv
# non_exersice.3e9e5dc9.csv
# front_raise.4.csv
# non_exersice.cbf8246c.csv
# non_exersice.335f586f.csv
# non_exersice.97c62ae3.csv
# non_exersice.fddff5a2.csv
# non_exersice.cc911fd8.csv
# non_exersice.2975ba4c.csv
# non_exersice.74d022ee.csv
# dumbell_row.109.csv
# non_exersice.94631aa0.csv
# non_exersice.57b07553.csv
# non_exersice.7808f80c.csv
# non_exersice.1594a44e.csv
# non_exersice.e490e602.csv
# non_exersice.b02892d0.csv
# front_raise.6.csv
# front_raise.106.csv
# dumbell_row.38.csv
# non_exersice.e4f6c74b.csv
# hammer_curl.125.csv
# shoulder_press.1.csv
# hammer_curl.119.csv
# hammer_curl.88.csv
# dumbell_row.10.csv
# non_exersice.dcfafce0.csv
# non_exersice.39d703c6.csv
# non_exersice.3138a078.csv
# non_exersice.2df68d70.csv
# non_exersice.01ca5593.csv
# shoulder_press.18.csv
# front_raise.12.csv
# shoulder_press.24.csv
# non_exersice.edc78334.csv
# curl.24.csv
# curl.30.csv
# curl.18.csv
# non_exersice.67ab543e.csv
# non_exersice.5d162926.csv
# non_exersice.fdb13954.csv
# curl.31.csv
# non_exersice.9bf25c44.csv
# shoulder_press.31.csv
# shoulder_press.25.csv
# non_exersice.fe26bcc8.csv
# front_raise.13.csv
# non_exersice.2083c200.csv
# non_exersice.7ca7fb48.csv
# non_exersice.330cb329.csv
# non_exersice.71df3d8d.csv
# non_exersice.556aae3c.csv
# non_exersice.4cbb2f4d.csv
# hammer_curl.76.csv
# non_exersice.c242b822.csv
# dumbell_row.11.csv
# hammer_curl.89.csv
# hammer_curl.118.csv
# non_exersice.c257366a.csv
# non_exersice.6a050943.csv
# front_raise.113.csv
# shoulder_press.0.csv
# hammer_curl.124.csv
# dumbell_row.39.csv
# front_raise.107.csv
# non_exersice.cdcdc8d9.csv
# front_raise.7.csv
# non_exersice.af13c9a1.csv
# non_exersice.86edeed0.csv
# dumbell_row.120.csv
# non_exersice.a8db61f8.csv
# dumbell_row.108.csv
# non_exersice.196c64ae.csv
# dumbell_row.118.csv
# non_exersice.dcb44fb1.csv
# front_raise.3.csv
# non_exersice.416c6643.csv
# non_exersice.bfd476d2.csv
# non_exersice.8246b591.csv
# hammer_curl.99.csv
# hammer_curl.108.csv
# shoulder_press.4.csv
# non_exersice.f3fc2e25.csv
# dumbell_row.29.csv
# hammer_curl.134.csv
# non_exersice.374527e7.csv
# hammer_curl.66.csv
# non_exersice.7b377c4b.csv
# non_exersice.b1fe228f.csv
# non_exersice.f74c5b81.csv
# non_exersice.b623c225.csv
# non_exersice.23c30291.csv
# shoulder_press.21.csv
# shoulder_press.35.csv
# non_exersice.f3fe51e9.csv
# curl.21.csv
# curl.35.csv
# curl.34.csv
# curl.20.csv
# non_exersice.df2b2621.csv
# non_exersice.56ac85bb.csv
# front_raise.16.csv
# non_exersice.7dd8fa13.csv
# shoulder_press.20.csv
# non_exersice.b8906496.csv
# non_exersice.0170bdc7.csv
# non_exersice.25df14cb.csv
# non_exersice.dfffffea.csv
# non_exersice.837537c5.csv
# non_exersice.21c50f02.csv
# non_exersice.dd7ed50b.csv
# non_exersice.1fe26bad.csv
# non_exersice.789b1e03.csv
# hammer_curl.135.csv
# front_raise.116.csv
# dumbell_row.28.csv
# non_exersice.f783f976.csv
# shoulder_press.5.csv
# hammer_curl.121.csv
# hammer_curl.109.csv
# dumbell_row.14.csv
# non_exersice.ef4377ba.csv
# non_exersice.bc6a6d91.csv
# non_exersice.45350b95.csv
# non_exersice.c987ee80.csv
# front_raise.2.csv
# non_exersice.fae52224.csv
# non_exersice.a9f5cdbf.csv
# non_exersice.e210a637.csv
# non_exersice.557c4123.csv
# non_exersice.faff23ae.csv
# non_exersice.3c7048cc.csv
# non_exersice.376478d9.csv
# dumbell_row.16.csv
# front_raise.128.csv
# non_exersice.c31056f7.csv
# front_raise.114.csv
# front_raise.100.csv
# hammer_curl.123.csv
# shoulder_press.7.csv
# non_exersice.200b6a96.csv
# non_exersice.4e634d18.csv
# non_exersice.35557754.csv
# hammer_curl.71.csv
# non_exersice.3127ad84.csv
# non_exersice.beb851e5.csv
# front_raise.28.csv
# shoulder_press.36.csv
# non_exersice.37358496.csv
# shoulder_press.22.csv
# non_exersice.f8b64ec6.csv
# front_raise.14.csv
# non_exersice.d717156c.csv
# non_exersice.a8054b4f.csv
# non_exersice.1f355059.csv
# curl.36.csv
# curl.22.csv
# front_raise.15.csv
# shoulder_press.23.csv
# non_exersice.79418922.csv
# front_raise.29.csv
# shoulder_press.37.csv
# non_exersice.6171c1f5.csv
# non_exersice.81381ebf.csv
# dumbell_row.8.csv
# non_exersice.1d6b882c.csv
# non_exersice.172e4190.csv
# non_exersice.b2bea573.csv
# non_exersice.6a104b0f.csv
# non_exersice.64f5e0e4.csv
# hammer_curl.70.csv
# non_exersice.2d4a266d.csv
# shoulder_press.6.csv
# hammer_curl.122.csv
# front_raise.101.csv
# hammer_curl.136.csv
# front_raise.115.csv
# front_raise.129.csv
# front_raise.1.csv
# non_exersice.f5129699.csv
# non_exersice.4d1f890c.csv
# non_exersice.ca059a97.csv
# non_exersice.3eba227b.csv
# non_exersice.b76c90a7.csv
# non_exersice.5a751a5e.csv
# shoulder_press.138.csv
# non_exersice.801ed344.csv
# front_raise.166.csv
# dumbell_row.58.csv
# hammer_curl.145.csv
# shoulder_press.104.csv
# dumbell_row.70.csv
# dumbell_row.64.csv
# shoulder_press.110.csv
# non_exersice.6213a97c.csv
# non_exersice.cbd98f49.csv
# hammer_curl.17.csv
# non_exersice.e40d1f3a.csv
# non_exersice.daf6c8a2.csv
# non_exersice.bdb7c8c1.csv
# non_exersice.36146832.csv
# non_exersice.e12f0184.csv
# non_exersice.3276ff05.csv
# non_exersice.7539cf7b.csv
# non_exersice.7805714f.csv
# curl.93.csv
# front_raise.72.csv
# non_exersice.9b9eed1e.csv
# front_raise.66.csv
# curl.87.csv
# non_exersice.dc4820a0.csv
# shoulder_press.50.csv
# shoulder_press.44.csv
# curl.50.csv
# curl.44.csv
# curl.117.csv
# shoulder_press.93.csv
# front_raise.99.csv
# curl.78.csv
# curl.103.csv
# shoulder_press.86.csv
# curl.102.csv
# curl.79.csv
# front_raise.98.csv
# curl.116.csv
# non_exersice.1b312a6f.csv
# shoulder_press.92.csv
# curl.45.csv
# curl.51.csv
# non_exersice.de5733f6.csv
# shoulder_press.51.csv
# non_exersice.b2cca949.csv
# curl.86.csv
# front_raise.67.csv
# front_raise.73.csv
# curl.92.csv
# non_exersice.b54a1504.csv
# non_exersice.7d9f9dbb.csv
# non_exersice.f5bf49bc.csv
# non_exersice.5ee402d9.csv
# non_exersice.7f784504.csv
# non_exersice.27a837a5.csv
# non_exersice.559e02f9.csv
# hammer_curl.16.csv
# dumbell_row.65.csv
# shoulder_press.111.csv
# shoulder_press.105.csv
# dumbell_row.71.csv
# hammer_curl.144.csv
# dumbell_row.59.csv
# front_raise.167.csv
# shoulder_press.139.csv
# non_exersice.2ba76d98.csv
# non_exersice.a8ca2720.csv
# non_exersice.9807aa2f.csv
# non_exersice.034e19cd.csv
# non_exersice.f3d045c2.csv
# non_exersice.ef3df43f.csv
# non_exersice.d8d12184.csv
# curl.9.csv
# non_exersice.37567bdd.csv
# front_raise.165.csv
# hammer_curl.146.csv
# non_exersice.93713816.csv
# shoulder_press.113.csv
# dumbell_row.67.csv
# dumbell_row.73.csv
# shoulder_press.107.csv
# hammer_curl.14.csv
# hammer_curl.28.csv
# non_exersice.70291c36.csv
# non_exersice.9770f33a.csv
# non_exersice.128c360c.csv
# non_exersice.97e5512d.csv
# non_exersice.025aec07.csv
# curl.84.csv
# curl.90.csv
# front_raise.71.csv
# front_raise.59.csv
# shoulder_press.47.csv
# shoulder_press.53.csv
# curl.47.csv
# non_exersice.3c005184.csv
# non_exersice.f64575df.csv
# curl.53.csv
# curl.128.csv
# curl.100.csv
# shoulder_press.84.csv
# shoulder_press.90.csv
# non_exersice.51acdf89.csv
# curl.114.csv
# shoulder_press.91.csv
# curl.115.csv
# curl.101.csv
# shoulder_press.85.csv
# curl.129.csv
# curl.52.csv
# non_exersice.2547f226.csv
# shoulder_press.52.csv
# non_exersice.762c413e.csv
# front_raise.58.csv
# non_exersice.78175c6a.csv
# shoulder_press.46.csv
# non_exersice.b50c180c.csv
# front_raise.70.csv
# non_exersice.d8d95aea.csv
# curl.91.csv
# curl.85.csv
# front_raise.64.csv
# non_exersice.d2b0dcae.csv
# hammer_curl.29.csv
# non_exersice.63fd8b2f.csv
# shoulder_press.106.csv
# shoulder_press.112.csv
# dumbell_row.66.csv
# front_raise.158.csv
# non_exersice.da40e6fe.csv
# hammer_curl.147.csv
# front_raise.164.csv
# non_exersice.4034b28f.csv
# non_exersice.19aa02cf.csv
# non_exersice.7f32199f.csv
# curl.8.csv
# non_exersice.a8437d00.csv
# non_exersice.e6f60327.csv
# non_exersice.2eb2c8e4.csv
# non_exersice.3822b12e.csv
# non_exersice.00bca1bb.csv
# dumbell_row.62.csv
# shoulder_press.116.csv
# shoulder_press.102.csv
# front_raise.148.csv
# hammer_curl.143.csv
# non_exersice.341ac290.csv
# non_exersice.aa299704.csv
# hammer_curl.11.csv
# non_exersice.fe8e927e.csv
# non_exersice.a2ac6e43.csv
# non_exersice.b980f282.csv
# non_exersice.da0c641a.csv
# shoulder_press.42.csv
# non_exersice.f444ee3c.csv
# front_raise.48.csv
# non_exersice.5a726b42.csv
# front_raise.60.csv
# curl.81.csv
# non_exersice.e05f669a.csv
# curl.95.csv
# front_raise.74.csv
# shoulder_press.81.csv
# curl.105.csv
# curl.111.csv
# non_exersice.e914594e.csv
# shoulder_press.95.csv
# curl.139.csv
# non_exersice.b8a95b4e.csv
# curl.56.csv
# non_exersice.bde05422.csv
# curl.57.csv
# curl.138.csv
# curl.43.csv
# curl.110.csv
# non_exersice.50d41a2e.csv
# shoulder_press.94.csv
# shoulder_press.80.csv
# curl.104.csv
# front_raise.75.csv
# curl.94.csv
# curl.80.csv
# front_raise.61.csv
# front_raise.49.csv
# shoulder_press.43.csv
# non_exersice.6204f495.csv
# non_exersice.d3df47c8.csv
# non_exersice.46996438.csv
# non_exersice.384b4120.csv
# non_exersice.751355f7.csv
# hammer_curl.10.csv
# non_exersice.9f79d05c.csv
# hammer_curl.38.csv
# non_exersice.c02ec4cc.csv
# non_exersice.9f164461.csv
# hammer_curl.142.csv
# front_raise.161.csv
# shoulder_press.103.csv
# non_exersice.32bc827d.csv
# front_raise.149.csv
# dumbell_row.77.csv
# non_exersice.46f649f7.csv
# dumbell_row.63.csv
# shoulder_press.117.csv
# non_exersice.c45fbcac.csv
# non_exersice.91ca594b.csv
# non_exersice.9538dc16.csv
# non_exersice.c8be0417.csv
# non_exersice.62bd16f4.csv
# non_exersice.949c9a83.csv
# non_exersice.b414ad4c.csv
# shoulder_press.101.csv
# shoulder_press.115.csv
# dumbell_row.61.csv
# dumbell_row.49.csv
# front_raise.177.csv
# non_exersice.cd613a8c.csv
# shoulder_press.129.csv
# front_raise.163.csv
# non_exersice.b118e9e1.csv
# hammer_curl.12.csv
# non_exersice.43f0de05.csv
# non_exersice.c5273e27.csv
# non_exersice.aa63430d.csv
# non_exersice.2898e253.csv
# shoulder_press.55.csv
# shoulder_press.41.csv
# shoulder_press.69.csv
# curl.96.csv
# curl.82.csv
# shoulder_press.96.csv
# curl.69.csv
# non_exersice.55dff103.csv
# curl.112.csv
# front_raise.88.csv
# non_exersice.ab2e9ccf.csv
# curl.106.csv
# shoulder_press.82.csv
# non_exersice.6b341911.csv
# curl.55.csv
# curl.40.csv
# non_exersice.70bc8065.csv
# curl.54.csv
# non_exersice.ec7f873c.csv
# curl.107.csv
# shoulder_press.83.csv
# shoulder_press.97.csv
# front_raise.89.csv
# curl.113.csv
# curl.83.csv
# non_exersice.6a339dfc.csv
# front_raise.62.csv
# shoulder_press.68.csv
# front_raise.76.csv
# curl.97.csv
# shoulder_press.40.csv
# shoulder_press.54.csv
# non_exersice.0dbb70ab.csv
# non_exersice.28fd4f6a.csv
# non_exersice.92288325.csv
# non_exersice.809cddae.csv
# non_exersice.03ae0aaf.csv
# non_exersice.733736a3.csv
# hammer_curl.13.csv
# non_exersice.0c03af44.csv
# hammer_curl.0.csv
# non_exersice.58ef2bcb.csv
# non_exersice.ffe2d399.csv
# shoulder_press.128.csv
# hammer_curl.141.csv
# front_raise.162.csv
# dumbell_row.48.csv
# shoulder_press.114.csv
# non_exersice.37893221.csv
# non_exersice.898a10dc.csv
# shoulder_press.100.csv
# non_exersice.c8cd2789.csv
# non_exersice.1c82e8bd.csv
# non_exersice.ba609a83.csv
# non_exersice.b170813d.csv
# Header: ('timestamp', 'ax', 'ay', 'az', 'q0', 'q1', 'q2', 'q3')
# Dataset shape: (1050, 500, 8)
# Number of samples: 1050
# Number of files 1050

# %% [markdown]
# ## Step 2: Split the data
#
# We should not include the test set in our analysis or scaling efforts, as that could introduce a bias.

# %%
### Shuffle and split dataset

# Use a seed in case we want to recreate the exact results
random.seed(SEED)

# Shuffle our dataset
X_y = list(zip(X_all, filenames))
random.shuffle(X_y)
X_all, filenames = zip(*X_y)

# Calculate number of validation and test samples to put aside (round down)
num_samples_test = int(TEST_RATIO * num_samples)

# The first `num_samples_test` samples of the shuffled list becomes the test set
X_test = X_all[:num_samples_test]
filenames_test = filenames[:num_samples_test]

# The remaining samples become the training set
X_train = X_all[num_samples_test:]
filenames_train = filenames[num_samples_test:]

# Convert data to Numpy arrays
X_train = np.asarray(X_train)
X_test = np.asarray(X_test)

# Print shapes of our sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (840, 500, 8)
# X_test shape: (210, 500, 8)

# %% [markdown]
# ## Step 3: Analyze the training data
#
# Look at the histograms to determine if scaling is required

# %%
### Reshape the data (drop timestamp column)
def flatten_data_for_analysis(X, num_channels):

  # Calculate number of rows in each channel (channel = different sensor reading)
  num_rows = X.shape[0] * X_train.shape[1]

  # Combine all data in each channel
  X_flatten = np.reshape(X, (num_rows, num_channels))

  # Drop the timestamp column--it will mess up our analysis
  X_flatten = np.delete(X_flatten, 0, axis=1)

  return X_flatten

# %%
### Examine the histograms of all the data

# Settings
num_bins = 80

# Flatten the data along each channel
X_train_flatten = flatten_data_for_analysis(X_train, num_channels)
channel_names_no_timestamp = channel_names[1:]

# Create subplots
num_hists = len(channel_names_no_timestamp)
fig, axs = plt.subplots(1, num_hists, figsize=(20,3))

# Create histogram for each category of data
for i in range(num_hists):
  _ = axs[i].hist(X_train_flatten[:, i], 
                  bins=num_bins)
  axs[i].title.set_text(channel_names_no_timestamp[i])

# %% [markdown]
# This look like fairly well-behaved data with Gaussian distributions. However, look at the X-axis range (the min and max values that each channel contains in our data).

# %%
### Try the histograms with the same scale

# Get the minimum and maximum values (the range)
min_val = X_train_flatten.min()
max_val = X_train_flatten.max()

# Create subplots
num_hists = len(channel_names_no_timestamp)
fig, axs = plt.subplots(1, num_hists, figsize=(20,3))

# Create histogram for each category of data
for i in range(num_hists):
  _ = axs[i].hist(X_train_flatten[:, i], 
                  bins=num_bins, 
                  range=(min_val, max_val))
  axs[i].title.set_text(channel_names_no_timestamp[i])

# %% [markdown]
# Whoa! If we graph using the same range, it looks like there's a lot more variance in our gyroscope data. However, that's simply becuase the gyroscope uses different units (and therefore has a different range of values) than our accelerometer. To fix this, we should standardize our data.

# %% [markdown]
# ## Step 4: Standardize the data
#
# Perform standarization so that our data, per-channel, has a mean of 0 and a standard deviation of 1.

# %%
### Function to calculate dataset metrics (mean, std dev, etc.) for each channel
def calc_metrics(X, ignore_first_col=False):

  # Flatten along the channels
  num_rows = X.shape[0] * X.shape[1]
  X_flatten = np.reshape(X, (num_rows, num_channels))

  # Calculate means, standard deviations, and ranges
  means = np.mean(X_flatten, axis=0)
  std_devs = np.std(X_flatten, axis=0)
  mins = np.min(X_flatten, axis=0)
  ranges = np.ptp(X_flatten, axis=0)

  # Drop the first column if requested
  if ignore_first_col:
    return (means[1:], std_devs[1:], mins[1:], ranges[1:])
  else:
    return (means, std_devs, mins, ranges)

# %%
### Function to perform standardization for a given set of data
def standardize_data(a, mean, std_dev):
  standardized_a = (a - mean) / std_dev
  return standardized_a

# %%
### Compute the metrics of the training data

# Compute metrics (drop timestamp column)
(means, std_devs, mins, ranges) = calc_metrics(X_train, ignore_first_col=True)

# Print out the results (drop timestamp column)
print(channel_names[1:])
means = [float("{:.4f}".format(x)) for x in means]
std_devs = [float("{:.4f}".format(x)) for x in std_devs]
print("Means:", means)
print("Std devs:", std_devs)
print("Mins:", [float("{:.4f}".format(x)) for x in mins])
print("Ranges:", [float("{:.4f}".format(x)) for x in ranges])
# Out:
# ('ax', 'ay', 'az', 'q0', 'q1', 'q2', 'q3')
# Means: [0.4401, 0.5026, 0.225, 0.5947, 0.2694, -0.0407, 0.2378]
# Std devs: [0.8218, 0.5361, 0.5233, 0.2392, 0.3975, 0.4034, 0.371]
# Mins: [-4.889, -4.433, -2.879, 0.0, -0.984, -0.98, -0.937]
# Ranges: [9.792, 9.336, 7.745, 0.997, 1.974, 1.957, 1.909]

# %% [markdown]
# **Record these values!** We will need them to perform preprocessing on the test dataset and for preprocessing raw data we capture during live inference (deployment).

# %% [markdown]
# ## Export Means and Std devs

# %%
import json
'''
Current config for inference
{
    "model_path": "../models/test.tflite",
    "means": [0.3981, 0.4978, 0.2766, 0.6055, 0.2624, -0.0003, 0.2684],
    "std_devs": [0.8194, 0.557, 0.5193, 0.2391, 0.3964, 0.3843, 0.3613],
    "buffer_size": 910,
    "class_names": ["curl", "front_raise", "shoulder_press", "non_exersice", "hammer_curl"],
    "comments": "CNN plus hammer_curl clas"
}
'''
config = {}
config["means"] = means
config["std_devs"] = std_devs

# Save the dictionary to a JSON file
with open('test.json', 'w') as f:
    json.dump(config, f)

# %%
### Standardize each channel (do NOT standardize the timestamp channel!)

# Initialize standardized data arrays
X_train_std = np.zeros(X_train.shape)
X_test_std = np.zeros(X_test.shape)

# Go through each channel in the training data
for i in range(len(channel_names)):
  
  # Skip the timestamp channel!
  if i == 0:
    X_train_std[:,:,i] = X_train[:,:,i]

  # Otherwise, perform standardization
  else:
    X_train_std[:,:,i] = standardize_data(X_train[:,:,i], 
                                          means[i - 1], 
                                          std_devs[i - 1])

# Go through each channel in the test data. Notice that we use the same means
# and standard deviations that we calculated from the training data!
for i in range(len(channel_names)):
  
  # Skip the timestamp channel!
  if i == 0:
    X_test_std[:,:,i] = X_test[:,:,i]

  # Otherwise, perform standardization
  else:
    X_test_std[:,:,i] = standardize_data(X_test[:,:,i], 
                                          means[i - 1], 
                                          std_devs[i - 1])
    
# Print shapes
print("X_train_std shape:", X_train_std.shape)
print("X_test_std shape:", X_test_std.shape)
# Out:
# X_train_std shape: (840, 500, 8)
# X_test_std shape: (210, 500, 8)

# %%
### Examine the metrics and histograms of the newly standardized data

# Compute metrics for the standardized data
(means, std_devs, mins, ranges) = calc_metrics(X_train_std, 
                                               ignore_first_col=True)
print(channel_names[1:])
print("Means:", [float("{:.4f}".format(x)) for x in means])
print("Std devs:", [float("{:.4f}".format(x)) for x in std_devs])
print("Mins:", [float("{:.4f}".format(x)) for x in mins])
print("Ranges:", [float("{:.4f}".format(x)) for x in ranges])

# Flatten the data along each channel
X_train_flatten = flatten_data_for_analysis(X_train_std, num_channels)
channel_names_no_timestamp = channel_names[1:]

# Create subplots
num_hists = len(channel_names_no_timestamp)
fig, axs = plt.subplots(1, num_hists, figsize=(20,3))

# Create histogram for each category of data
for i in range(num_hists):
  _ = axs[i].hist(X_train_flatten[:, i], 
                  bins=num_bins)
  axs[i].title.set_text(channel_names_no_timestamp[i])
# Out:
# ('ax', 'ay', 'az', 'q0', 'q1', 'q2', 'q3')
# Means: [0.0, 0.0, 0.0, -0.0001, 0.0001, -0.0001, -0.0]
# Std devs: [0.9999, 0.9999, 1.0, 1.0, 1.0001, 0.9999, 1.0]
# Mins: [-6.4847, -9.2065, -5.9316, -2.4862, -3.1532, -2.3285, -3.1666]
# Ranges: [11.9153, 17.4147, 14.8003, 4.1681, 4.966, 4.8513, 5.1456]

# %% [markdown]
# Check the metrics and histograms above. All means should be 0.0 and all standard deviations should be 1.0. Do the ranges seem more reasonable?

# %% [markdown]
# ## Steap 5: Store preprocessed data in CSV files

# %%
### Function to write header and data to CSV files to given directory
def write_csv_data(header, data, filenames, dir_path):

  # Go through each filename - should be in the same order as our samples in X
  for i, filename in enumerate(filenames):

    # Write header and data (for that one sample) to the CSV file
    file_path = os.path.join(dir_path, filename)
    with open(file_path, 'w') as f:
      csv_writer = csv.writer(f, delimiter=',')
      csv_writer.writerow(header)
      csv_writer.writerows(data[i])

# %%
### Delete output directory (if it exists) and recreate it
if os.path.exists(OUT_PATH):
  shutil.rmtree(OUT_PATH)
os.makedirs(os.path.join(OUT_PATH, TRAIN_DIR))
os.makedirs(os.path.join(OUT_PATH, TEST_DIR))

# %%
### Write training and test data to .csv files in separate directories

# Write out training data
dir_path = os.path.join(OUT_PATH, TRAIN_DIR)
write_csv_data(channel_names, X_train_std, filenames_train, dir_path)

# Write out test data
dir_path = os.path.join(OUT_PATH, TEST_DIR)
write_csv_data(channel_names, X_test_std, filenames_test, dir_path)

# %%
### Zip output directory
# %cd {OUT_PATH}
# !zip -FS -r -q {OUT_ZIP} *
# %cd {HOME_PATH}
# Out:
# /Users/moon/work/dotyklab/dotykGesture/gestures/notebooks/out
# /Users/moon/work/dotyklab/dotykGesture/gestures/notebooks

# %%
# %cd {HOME_PATH}
# !pwd
# Out:
# /Users/moon/work/dotyklab/dotykGesture/gestures/notebooks
# /Users/moon/work/dotyklab/dotykGesture/gestures/notebooks
