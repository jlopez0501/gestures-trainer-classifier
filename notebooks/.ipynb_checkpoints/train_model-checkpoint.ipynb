# %%
import os
import glob
import json
import numpy as np
import pandas as pd
import numpy.typing as npt
import matplotlib.pyplot as plt
from IPython.display import Video
from scipy.spatial.transform import Rotation

from sklearn.model_selection import train_test_split
from scipy.signal import find_peaks
import seaborn as sb
import itertools


import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

#plt.style.use("seaborn-deep")

sb.set_palette("husl",3)
sb.set_style("whitegrid")
# Out:
# 2024-03-05 22:47:09.290977: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def load_and_label_data(file_paths, label):
    """Load data from multiple CSV files and assign a label."""
    data_list = []
    for file_path in file_paths:
        df = pd.read_csv(file_path)
        # The CSV contains 'ax', 'ay', 'az', 'q0', 'q1', 'q2', 'q3'
        df['label'] = label
        data_list.append(df)
    return pd.concat(data_list)

# %% [markdown]
# ### Load front_raise data

# %%
PATH_TO_EXERCISE_FOLDER = "../data/cleaned/front_raise/"
excersise_files = sorted(glob.glob(os.path.join(PATH_TO_EXERCISE_FOLDER, "*.csv")))
print(excersise_files)
# Out:
# ['../data/cleaned/front_raise/front_raise1.csv', '../data/cleaned/front_raise/front_raise10.csv', '../data/cleaned/front_raise/front_raise11.csv', '../data/cleaned/front_raise/front_raise12.csv', '../data/cleaned/front_raise/front_raise13.csv', '../data/cleaned/front_raise/front_raise14.csv', '../data/cleaned/front_raise/front_raise15.csv', '../data/cleaned/front_raise/front_raise16.csv', '../data/cleaned/front_raise/front_raise17.csv', '../data/cleaned/front_raise/front_raise18.csv', '../data/cleaned/front_raise/front_raise19.csv', '../data/cleaned/front_raise/front_raise2.csv', '../data/cleaned/front_raise/front_raise20.csv', '../data/cleaned/front_raise/front_raise21.csv', '../data/cleaned/front_raise/front_raise22.csv', '../data/cleaned/front_raise/front_raise23.csv', '../data/cleaned/front_raise/front_raise24.csv', '../data/cleaned/front_raise/front_raise25.csv', '../data/cleaned/front_raise/front_raise26.csv', '../data/cleaned/front_raise/front_raise27.csv', '../data/cleaned/front_raise/front_raise28.csv', '../data/cleaned/front_raise/front_raise29.csv', '../data/cleaned/front_raise/front_raise3.csv', '../data/cleaned/front_raise/front_raise30.csv', '../data/cleaned/front_raise/front_raise31.csv', '../data/cleaned/front_raise/front_raise32.csv', '../data/cleaned/front_raise/front_raise33.csv', '../data/cleaned/front_raise/front_raise34.csv', '../data/cleaned/front_raise/front_raise35.csv', '../data/cleaned/front_raise/front_raise36.csv', '../data/cleaned/front_raise/front_raise37.csv', '../data/cleaned/front_raise/front_raise38.csv', '../data/cleaned/front_raise/front_raise39.csv', '../data/cleaned/front_raise/front_raise4.csv', '../data/cleaned/front_raise/front_raise40.csv', '../data/cleaned/front_raise/front_raise41.csv', '../data/cleaned/front_raise/front_raise42.csv', '../data/cleaned/front_raise/front_raise43.csv', '../data/cleaned/front_raise/front_raise44.csv', '../data/cleaned/front_raise/front_raise45.csv', '../data/cleaned/front_raise/front_raise46.csv', '../data/cleaned/front_raise/front_raise47.csv', '../data/cleaned/front_raise/front_raise48.csv', '../data/cleaned/front_raise/front_raise49.csv', '../data/cleaned/front_raise/front_raise5.csv', '../data/cleaned/front_raise/front_raise50.csv', '../data/cleaned/front_raise/front_raise6.csv', '../data/cleaned/front_raise/front_raise7.csv', '../data/cleaned/front_raise/front_raise8.csv', '../data/cleaned/front_raise/front_raise9.csv']

# %%
completedf_front_raise = load_and_label_data(excersise_files, 'front_raise')

# %%
completedf_front_raise
# Out:
#        timeMs     q0     q1     q2     q3        label
# 0      106919  0.004  0.669 -0.004  0.743  front_raise
# 1      106935  0.000  0.674 -0.007  0.738  front_raise
# 2      106951  0.002 -0.679  0.011 -0.734  front_raise
# 3      106967  0.003 -0.683  0.014 -0.731  front_raise
# 4      106983  0.004 -0.685  0.016 -0.728  front_raise
# ...       ...    ...    ...    ...    ...          ...
# 1061  1223371  0.049  0.677  0.079  0.730  front_raise
# 1062  1223388  0.033  0.678  0.081  0.729  front_raise
# 1063  1223404  0.020  0.679  0.083  0.729  front_raise
# 1064  1223420  0.009  0.680  0.086  0.728  front_raise
# 1065  1223436  0.001 -0.680 -0.090 -0.727  front_raise
#
# [67233 rows x 6 columns]

# %% [markdown]
# ### Load shoulder_press data

# %%
PATH_TO_EXERCISE_FOLDER = "../data/cleaned/shoulder_press/"
excersise_files = sorted(glob.glob(os.path.join(PATH_TO_EXERCISE_FOLDER, "*.csv")))
print(excersise_files)
# Out:
# ['../data/cleaned/shoulder_press/shoulder_press1.csv', '../data/cleaned/shoulder_press/shoulder_press10.csv', '../data/cleaned/shoulder_press/shoulder_press11.csv', '../data/cleaned/shoulder_press/shoulder_press12.csv', '../data/cleaned/shoulder_press/shoulder_press13.csv', '../data/cleaned/shoulder_press/shoulder_press14.csv', '../data/cleaned/shoulder_press/shoulder_press15.csv', '../data/cleaned/shoulder_press/shoulder_press16.csv', '../data/cleaned/shoulder_press/shoulder_press17.csv', '../data/cleaned/shoulder_press/shoulder_press18.csv', '../data/cleaned/shoulder_press/shoulder_press19.csv', '../data/cleaned/shoulder_press/shoulder_press2.csv', '../data/cleaned/shoulder_press/shoulder_press20.csv', '../data/cleaned/shoulder_press/shoulder_press21.csv', '../data/cleaned/shoulder_press/shoulder_press22.csv', '../data/cleaned/shoulder_press/shoulder_press23.csv', '../data/cleaned/shoulder_press/shoulder_press24.csv', '../data/cleaned/shoulder_press/shoulder_press25.csv', '../data/cleaned/shoulder_press/shoulder_press26.csv', '../data/cleaned/shoulder_press/shoulder_press27.csv', '../data/cleaned/shoulder_press/shoulder_press28.csv', '../data/cleaned/shoulder_press/shoulder_press29.csv', '../data/cleaned/shoulder_press/shoulder_press3.csv', '../data/cleaned/shoulder_press/shoulder_press30.csv', '../data/cleaned/shoulder_press/shoulder_press31.csv', '../data/cleaned/shoulder_press/shoulder_press32.csv', '../data/cleaned/shoulder_press/shoulder_press33.csv', '../data/cleaned/shoulder_press/shoulder_press34.csv', '../data/cleaned/shoulder_press/shoulder_press35.csv', '../data/cleaned/shoulder_press/shoulder_press36.csv', '../data/cleaned/shoulder_press/shoulder_press37.csv', '../data/cleaned/shoulder_press/shoulder_press38.csv', '../data/cleaned/shoulder_press/shoulder_press39.csv', '../data/cleaned/shoulder_press/shoulder_press4.csv', '../data/cleaned/shoulder_press/shoulder_press40.csv', '../data/cleaned/shoulder_press/shoulder_press41.csv', '../data/cleaned/shoulder_press/shoulder_press42.csv', '../data/cleaned/shoulder_press/shoulder_press43.csv', '../data/cleaned/shoulder_press/shoulder_press44.csv', '../data/cleaned/shoulder_press/shoulder_press45.csv', '../data/cleaned/shoulder_press/shoulder_press46.csv', '../data/cleaned/shoulder_press/shoulder_press47.csv', '../data/cleaned/shoulder_press/shoulder_press48.csv', '../data/cleaned/shoulder_press/shoulder_press49.csv', '../data/cleaned/shoulder_press/shoulder_press5.csv', '../data/cleaned/shoulder_press/shoulder_press50.csv', '../data/cleaned/shoulder_press/shoulder_press6.csv', '../data/cleaned/shoulder_press/shoulder_press7.csv', '../data/cleaned/shoulder_press/shoulder_press8.csv', '../data/cleaned/shoulder_press/shoulder_press9.csv']

# %%
completedf_shoulder_press = load_and_label_data(excersise_files, 'shoulder_press')

# %%
completedf_shoulder_press
# Out:
#        timeMs     q0     q1     q2     q3           label
# 0     4493087  0.519  0.260  0.080  0.810  shoulder_press
# 1     4493103  0.519  0.260  0.080  0.810  shoulder_press
# 2     4493120  0.519  0.260  0.080  0.810  shoulder_press
# 3     4493137  0.519  0.260  0.080  0.810  shoulder_press
# 4     4493153  0.519  0.260  0.080  0.810  shoulder_press
# ...       ...    ...    ...    ...    ...             ...
# 1224  4970303  0.743 -0.118  0.517  0.408  shoulder_press
# 1225  4970330  0.742 -0.084  0.529  0.404  shoulder_press
# 1226  4970346  0.739 -0.051  0.539  0.400  shoulder_press
# 1227  4970362  0.736 -0.016  0.549  0.397  shoulder_press
# 1228  4970378  0.731  0.019  0.558  0.392  shoulder_press
#
# [53977 rows x 6 columns]

# %% [markdown]
# ### Load non_exercise data

# %%
PATH_TO_EXERCISE_FOLDER = "../data/cleaned/non_exersice/"
non_excersise_files = sorted(glob.glob(os.path.join(PATH_TO_EXERCISE_FOLDER, "*.csv")))
print(non_excersise_files)
# Out:
# ['../data/cleaned/non_exersice/front_raise10_non_exersice.csv', '../data/cleaned/non_exersice/front_raise11_non_exersice.csv', '../data/cleaned/non_exersice/front_raise12_non_exersice.csv', '../data/cleaned/non_exersice/front_raise13_non_exersice.csv', '../data/cleaned/non_exersice/front_raise14_non_exersice.csv', '../data/cleaned/non_exersice/front_raise15_non_exersice.csv', '../data/cleaned/non_exersice/front_raise16_non_exersice.csv', '../data/cleaned/non_exersice/front_raise17_non_exersice.csv', '../data/cleaned/non_exersice/front_raise18_non_exersice.csv', '../data/cleaned/non_exersice/front_raise19_non_exersice.csv', '../data/cleaned/non_exersice/front_raise1_non_exersice.csv', '../data/cleaned/non_exersice/front_raise20_non_exersice.csv', '../data/cleaned/non_exersice/front_raise21_non_exersice.csv', '../data/cleaned/non_exersice/front_raise22_non_exersice.csv', '../data/cleaned/non_exersice/front_raise23_non_exersice.csv', '../data/cleaned/non_exersice/front_raise24_non_exersice.csv', '../data/cleaned/non_exersice/front_raise25_non_exersice.csv', '../data/cleaned/non_exersice/front_raise26_non_exersice.csv', '../data/cleaned/non_exersice/front_raise27_non_exersice.csv', '../data/cleaned/non_exersice/front_raise28_non_exersice.csv', '../data/cleaned/non_exersice/front_raise29_non_exersice.csv', '../data/cleaned/non_exersice/front_raise2_non_exersice.csv', '../data/cleaned/non_exersice/front_raise30_non_exersice.csv', '../data/cleaned/non_exersice/front_raise31_non_exersice.csv', '../data/cleaned/non_exersice/front_raise32_non_exersice.csv', '../data/cleaned/non_exersice/front_raise33_non_exersice.csv', '../data/cleaned/non_exersice/front_raise34_non_exersice.csv', '../data/cleaned/non_exersice/front_raise35_non_exersice.csv', '../data/cleaned/non_exersice/front_raise36_non_exersice.csv', '../data/cleaned/non_exersice/front_raise37_non_exersice.csv', '../data/cleaned/non_exersice/front_raise38_non_exersice.csv', '../data/cleaned/non_exersice/front_raise39_non_exersice.csv', '../data/cleaned/non_exersice/front_raise3_non_exersice.csv', '../data/cleaned/non_exersice/front_raise40_non_exersice.csv', '../data/cleaned/non_exersice/front_raise41_non_exersice.csv', '../data/cleaned/non_exersice/front_raise42_non_exersice.csv', '../data/cleaned/non_exersice/front_raise43_non_exersice.csv', '../data/cleaned/non_exersice/front_raise44_non_exersice.csv', '../data/cleaned/non_exersice/front_raise45_non_exersice.csv', '../data/cleaned/non_exersice/front_raise46_non_exersice.csv', '../data/cleaned/non_exersice/front_raise47_non_exersice.csv', '../data/cleaned/non_exersice/front_raise48_non_exersice.csv', '../data/cleaned/non_exersice/front_raise49_non_exersice.csv', '../data/cleaned/non_exersice/front_raise4_non_exersice.csv', '../data/cleaned/non_exersice/front_raise50_non_exersice.csv', '../data/cleaned/non_exersice/front_raise5_non_exersice.csv', '../data/cleaned/non_exersice/front_raise6_non_exersice.csv', '../data/cleaned/non_exersice/front_raise7_non_exersice.csv', '../data/cleaned/non_exersice/front_raise8_non_exersice.csv', '../data/cleaned/non_exersice/front_raise9_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press10_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press11_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press12_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press13_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press14_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press15_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press16_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press17_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press18_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press19_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press1_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press20_non_exersice.csv', '../data/cleaned/non_exersice/shoulder_press21_non_exersice.csv', ' ...

# %%
completedf_non_exersice_press = load_and_label_data(non_excersise_files, 'non_exersice')

# %%
completedf_non_exersice_press
# Out:
#       timeMs     q0     q1     q2     q3         label
# 0    1232145  0.684  0.328  0.137  0.637  non_exersice
# 1    1232162  0.681  0.329  0.141  0.638  non_exersice
# 2    1232179  0.679  0.329  0.145  0.640  non_exersice
# 3    1232195  0.677  0.331  0.148  0.641  non_exersice
# 4    1232211  0.675  0.332  0.152  0.641  non_exersice
# ..       ...    ...    ...    ...    ...           ...
# 854  4948829  0.466  0.591  0.536  0.382  non_exersice
# 855  4948845  0.464  0.590  0.537  0.385  non_exersice
# 856  4948861  0.462  0.590  0.538  0.387  non_exersice
# 857  4948878  0.459  0.590  0.539  0.388  non_exersice
# 858  4948894  0.457  0.589  0.541  0.389  non_exersice
#
# [85368 rows x 6 columns]

# %% [markdown]
# ### Concatenate into one dataframe

# %%
df_concatenated = pd.concat([completedf_front_raise, completedf_shoulder_press, completedf_non_exersice_press], ignore_index=True)

# %%
df_concatenated
# Out:
#          timeMs     q0     q1     q2     q3         label
# 0        106919  0.004  0.669 -0.004  0.743   front_raise
# 1        106935  0.000  0.674 -0.007  0.738   front_raise
# 2        106951  0.002 -0.679  0.011 -0.734   front_raise
# 3        106967  0.003 -0.683  0.014 -0.731   front_raise
# 4        106983  0.004 -0.685  0.016 -0.728   front_raise
# ...         ...    ...    ...    ...    ...           ...
# 206573  4948829  0.466  0.591  0.536  0.382  non_exersice
# 206574  4948845  0.464  0.590  0.537  0.385  non_exersice
# 206575  4948861  0.462  0.590  0.538  0.387  non_exersice
# 206576  4948878  0.459  0.590  0.539  0.388  non_exersice
# 206577  4948894  0.457  0.589  0.541  0.389  non_exersice
#
# [206578 rows x 6 columns]

# %% [markdown]
# ### Split into X, Y

# %%
def split_sequences(dataframe, sequence_length):
    """Split the dataframe into sequences of a given length, including all relevant columns."""
    X, y = [], []
    columns_of_interest = ['q0', 'q1', 'q2', 'q3']
    for i in range(0, len(dataframe) - sequence_length + 1, sequence_length):
        sequence = dataframe.iloc[i:i+sequence_length][columns_of_interest]
        label = dataframe.iloc[i]['label']
        X.append(sequence.values)
        y.append(label)
    return np.array(X), np.array(y)

# %%
x, y = split_sequences(df_concatenated, 500)

# %%
len(x), len(y)
# Out:
# (413, 413)

# %% [markdown]
# ## Model Train

# %% [markdown]
# ### Split into train, test, val set

# %%
X_train_val, X_val, y_train_val, y_val = train_test_split(x, y, test_size=0.1)
X_train, X_test, y_train, y_test = train_test_split(X_train_val, y_train_val, test_size=0.1)

# %%
len(np.unique(y_train))
# Out:
# 3

# %%
y_train.shape, X_train.shape
# Out:
# ((333,), (333, 500, 4))

# %%
y_test.shape, X_test.shape
# Out:
# ((38,), (38, 500, 4))

# %%
y_val.shape, X_val.shape
# Out:
# ((42,), (42, 500, 4))

# %% [markdown]
# ### Convert to one hot encoding

# %%
class_names = np.unique(y_train)
num_classes = len(np.unique(y_train))
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Convert text labels into numeric identifiers
y_train_encoded = label_encoder.fit_transform(y_train)

# Convert numeric labels into one-hot
y_train_one_hot = to_categorical(y_train_encoded)


# Convert text labels into numeric identifiers
y_val_encoded = label_encoder.fit_transform(y_val)


# Convert numeric labels into one-hot
y_val_one_hot = to_categorical(y_val_encoded)

# Convert text labels into numeric identifiers
y_test_encoded = label_encoder.fit_transform(y_test)

# Convert numeric labels into one-hot
y_test_one_hot = to_categorical(y_test_encoded)

# %% [markdown]
# ### Define model

# %%
# Define the model
inputs = tf.keras.Input(shape=(500, 4))

# Apply Dense layers to the inputs
layer = keras.layers.Dense(128, activation=tf.nn.relu6)(inputs)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)

# Add GlobalAveragePooling1D to reduce dimensionality
layer = keras.layers.GlobalAveragePooling1D()(layer)

# Final layer for classification
outputs = keras.layers.Dense(len(np.unique(y_train)), activation="softmax")(layer)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 500, 4)]          0
#
#  dense (Dense)               (None, 500, 128)          640
#
#  dropout (Dropout)           (None, 500, 128)          0
#
#  dense_1 (Dense)             (None, 500, 64)           8256
#
#  dropout_1 (Dropout)         (None, 500, 64)           0
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 9,091
# Trainable params: 9,091
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train model

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', 
                                              patience=50)

# Start training
print(X_train.shape)
history = model.fit(X_train, y_train_one_hot,
                    epochs=200,
                    batch_size=16,
                    validation_data=(X_val, y_val_one_hot),
                    callbacks=[checkpoint, earlystopping],
                    )
# Out:
# (333, 500, 4)
# Epoch 1/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0
200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2412 - accuracy: 0.9125
# Epoch 37: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 29ms/step - loss: 0.2456 - accuracy: 0.9069 - val_loss: 0.3348 - val_accuracy: 0.8810
# Epoch 38/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2560 - accuracy: 0.9062
# Epoch 38: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 28ms/step - loss: 0.2470 - accuracy: 0.9099 - val_loss: 0.3548 - val_accuracy: 0.8810
# Epoch 39/200
# 21/21 [==============================] - ETA: 0s - loss: 0.2459 - accuracy: 0.9099
# Epoch 39: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 30ms/step - loss: 0.2459 - accuracy: 0.9099 - val_loss: 0.3455 - val_accuracy: 0.8810
# Epoch 40/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2474 - accuracy: 0.9094
# Epoch 40: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 30ms/step - loss: 0.2465 - accuracy: 0.9099 - val_loss: 0.3394 - val_accuracy: 0.8810
# Epoch 41/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2369 - accuracy: 0.9125
# Epoch 41: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 28ms/step - loss: 0.2415 - accuracy: 0.9069 - val_loss: 0.3434 - val_accuracy: 0.8810
# Epoch 42/200
# 19/21 [==========================>...] - ETA: 0s - loss: 0.2375 - accuracy: 0.9046
# Epoch 42: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 28ms/step - loss: 0.2416 - accuracy: 0.9039 - val_loss: 0.3540 - val_accuracy: 0.8810
# Epoch 43/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2407 - accuracy: 0.9156
# Epoch 43: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 29ms/step - loss: 0.2375 - accuracy: 0.9159 - val_loss: 0.3212 - val_accuracy: 0.8810
# Epoch 44/200
# 19/21 [==========================>...] - ETA: 0s - loss: 0.2434 - accuracy: 0.9046
# Epoch 44: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 35ms/step - loss: 0.2517 - accuracy: 0.9039 - val_loss: 0.3907 - val_accuracy: 0.8810
# Epoch 45/200
# 21/21 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 0.9129
# Epoch 45: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 30ms/step - loss: 0.2405 - accuracy: 0.9129 - val_loss: 0.3485 - val_accuracy: 0.8810
# Epoch 46/200
# 19/21 [==========================>...] - ETA: 0s - loss: 0.2423 - accuracy: 0.9079
# Epoch 46: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 30ms/step - loss: 0.2356 - accuracy: 0.9129 - val_loss: 0.3517 - val_accuracy: 0.8810
# Epoch 47/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2446 - accuracy: 0.9094
# Epoch 47: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 30ms/step - loss: 0.2376 - accuracy: 0.9129 - val_loss: 0.3556 - val_accuracy: 0.8810
# Epoch 48/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2343 - accuracy: 0.9125
# Epoch 48: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 29ms/step - loss: 0.2309 - accuracy: 0.9159 - val_loss: 0.3106 - val_accuracy: 0.8810
# Epoch 49/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2467 - accuracy: 0.9062
# Epoch 49: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 28ms/step - loss: 0.2387 - accuracy: 0.9099 - val_loss: 0.3597 - val_accuracy: 0.8810
# Epoch 50/200
# 19/21 [==========================>...] - ETA: 0s - loss: 0.2480 - accuracy: 0.9013
# Epoch 50: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 28ms/step - loss: 0.2438 - accuracy: 0.9069 - val_loss: 0.3644 - val_accuracy: 0.8810
# Epoch 51/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2384 - accuracy: 0.9062
# Epoch 51: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 29ms/step - loss: 0.2343 - accuracy: 0.9069 - val_loss: 0.3556 - val_accuracy: 0.8810
# Epoch 52/200
# 20/21 [===========================>..] - ETA: 0s - loss: 0.2292 - accuracy: 0.9156
# Epoch 52: val_accuracy did not improve from 0.88095
# 21/21 [==============================] - 1s 29ms/step - loss: 0.2263 - accuracy: 0.9159 - val_loss: 0.3236 - val_accuracy: 0.8810

# %% [markdown]
# ### Plot graph

# %%
# Visualize the training history to see whether you're overfitting.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')
plt.grid()
plt.show()

# %% [markdown]
# ### Plot confusion matrix

# %%
loss, accuracy = model.evaluate(X_test, y_test_one_hot)
# Out:
# 2/2 [==============================] - 0s 24ms/step - loss: 0.2401 - accuracy: 0.8947

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """Plots the confusion matrix."""
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=55)
  plt.yticks(tick_marks, classes)
  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
              horizontalalignment="center",
              color="white" if cm[i, j] > thresh else "black")

  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.tight_layout()

# Classify pose in the TEST dataset using the trained model
y_pred = model.predict(X_test)

# Convert the prediction result to class name
y_pred_label = [class_names[i] for i in np.argmax(y_pred, axis=1)]
y_true_label = [class_names[i] for i in np.argmax(y_test_one_hot, axis=1)]

# Plot the confusion matrix
cm = confusion_matrix(np.argmax(y_test_one_hot, axis=1), np.argmax(y_pred, axis=1))
plot_confusion_matrix(cm,
                      class_names,
                      title ='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label, y_pred_label))
# Out:
# 2/2 [==============================] - 0s 6ms/step
# Confusion matrix, without normalization
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#    front_raise       1.00      0.77      0.87        13
#   non_exersice       0.82      1.00      0.90        18
# shoulder_press       1.00      0.86      0.92         7
#
#       accuracy                           0.89        38
#      macro avg       0.94      0.88      0.90        38
#   weighted avg       0.91      0.89      0.89        38
# /var/folders/c5/xpfx3gxx5d34j23111nbtn000000gn/T/ipykernel_50695/1767718340.py:14: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
