# %%
import os
import glob
import json
import numpy as np
import pandas as pd
import numpy.typing as npt
import matplotlib.pyplot as plt
from IPython.display import Video
from scipy.spatial.transform import Rotation

from sklearn.model_selection import train_test_split
from scipy.signal import find_peaks
import seaborn as sb
import itertools


import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

#plt.style.use("seaborn-deep")

sb.set_palette("husl",3)
sb.set_style("whitegrid")
# Out:
# 2024-02-26 16:44:26.394439: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 16:44:26.502766: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-02-26 16:44:26.502787: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-02-26 16:44:27.029193: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-02-26 16:44:27.029272: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-02-26 16:44:27.029279: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
PATH_TO_EXERCISE_FOLDER = "Exercises/front_raise/"
excersise_files = sorted(glob.glob(os.path.join(PATH_TO_EXERCISE_FOLDER, "*.csv")))
print(excersise_files)
# Out:
# ['Exercises/front_raise/front_raise1.csv', 'Exercises/front_raise/front_raise10.csv', 'Exercises/front_raise/front_raise11.csv', 'Exercises/front_raise/front_raise12.csv', 'Exercises/front_raise/front_raise13.csv', 'Exercises/front_raise/front_raise14.csv', 'Exercises/front_raise/front_raise15.csv', 'Exercises/front_raise/front_raise16.csv', 'Exercises/front_raise/front_raise17.csv', 'Exercises/front_raise/front_raise18.csv', 'Exercises/front_raise/front_raise19.csv', 'Exercises/front_raise/front_raise2.csv', 'Exercises/front_raise/front_raise20.csv', 'Exercises/front_raise/front_raise3.csv', 'Exercises/front_raise/front_raise4.csv', 'Exercises/front_raise/front_raise5.csv', 'Exercises/front_raise/front_raise6.csv', 'Exercises/front_raise/front_raise7.csv', 'Exercises/front_raise/front_raise8.csv', 'Exercises/front_raise/front_raise9.csv']

# %%
def load_and_label_data(file_paths, label):
    """Load data from multiple CSV files and assign a label."""
    data_list = []
    for file_path in file_paths:
        df = pd.read_csv(file_path)
        # The CSV contains 'ax', 'ay', 'az', 'q0', 'q1', 'q2', 'q3'
        df['label'] = label
        data_list.append(df)
    return pd.concat(data_list)

# %%
completedf_front_raise = load_and_label_data(excersise_files, 'front_raise')

# %%
completedf_front_raise
# Out:
#            ax      ay      az     q0     q1     q2     q3        label
# 0      8272.0 -1434.0  1282.0  0.343 -0.629 -0.196 -0.669  front_raise
# 1      8712.0 -1518.0  1006.0  0.341 -0.630 -0.192 -0.670  front_raise
# 2      9318.0 -1464.0  1060.0  0.339 -0.632 -0.187 -0.671  front_raise
# 3      9922.0 -1780.0  1040.0  0.338 -0.634 -0.182 -0.672  front_raise
# 4     10366.0 -1970.0   850.0  0.338 -0.635 -0.176 -0.672  front_raise
# ...       ...     ...     ...    ...    ...    ...    ...          ...
# 1824   8700.0  -440.0   896.0  0.498  0.392 -0.553  0.541  front_raise
# 1825   9612.0  -424.0  1144.0  0.492  0.391 -0.552  0.548  front_raise
# 1826  10066.0   -78.0  1214.0  0.488  0.389 -0.551  0.554  front_raise
# 1827   9986.0  -642.0   984.0  0.484  0.387 -0.550  0.560  front_raise
# 1828   9602.0 -1152.0  1150.0  0.480  0.385 -0.549  0.566  front_raise
#
# [42791 rows x 8 columns]

# %%
PATH_TO_EXERCISE_FOLDER = "Exercises/shoulder_press/"
excersise_files = sorted(glob.glob(os.path.join(PATH_TO_EXERCISE_FOLDER, "*.csv")))
print(excersise_files)
# Out:
# ['Exercises/shoulder_press/shoulder_press1.csv', 'Exercises/shoulder_press/shoulder_press10.csv', 'Exercises/shoulder_press/shoulder_press11.csv', 'Exercises/shoulder_press/shoulder_press12.csv', 'Exercises/shoulder_press/shoulder_press13.csv', 'Exercises/shoulder_press/shoulder_press14.csv', 'Exercises/shoulder_press/shoulder_press15.csv', 'Exercises/shoulder_press/shoulder_press16.csv', 'Exercises/shoulder_press/shoulder_press17.csv', 'Exercises/shoulder_press/shoulder_press18.csv', 'Exercises/shoulder_press/shoulder_press19.csv', 'Exercises/shoulder_press/shoulder_press2.csv', 'Exercises/shoulder_press/shoulder_press20.csv', 'Exercises/shoulder_press/shoulder_press3.csv', 'Exercises/shoulder_press/shoulder_press4.csv', 'Exercises/shoulder_press/shoulder_press5.csv', 'Exercises/shoulder_press/shoulder_press6.csv', 'Exercises/shoulder_press/shoulder_press7.csv', 'Exercises/shoulder_press/shoulder_press8.csv', 'Exercises/shoulder_press/shoulder_press9.csv']

# %%
completedf_shoulder_press = load_and_label_data(excersise_files, 'shoulder_press')

# %%
completedf_shoulder_press
# Out:
#            ax      ay      az     q0     q1     q2     q3           label
# 0       190.0  8114.0   482.0  0.725  0.688 -0.034 -0.019  shoulder_press
# 1       188.0  8190.0   488.0  0.725  0.688 -0.034 -0.019  shoulder_press
# 2       210.0  8248.0   516.0  0.725  0.688 -0.034 -0.019  shoulder_press
# 3       212.0  8136.0   426.0  0.725  0.688 -0.034 -0.019  shoulder_press
# 4       170.0  8150.0   438.0  0.725  0.688 -0.034 -0.019  shoulder_press
# ...       ...     ...     ...    ...    ...    ...    ...             ...
# 1670  -9661.0 -1312.0 -2406.0  0.714 -0.015  0.699  0.030  shoulder_press
# 1671 -10159.0 -2438.0 -1764.0  0.725  0.005  0.689  0.021  shoulder_press
# 1672  -8901.0 -2868.0 -2208.0  0.736  0.029  0.677  0.010  shoulder_press
# 1673  -7483.0 -1260.0 -3020.0  0.746  0.054  0.664 -0.004  shoulder_press
# 1674  -6339.0  2196.0 -2828.0  0.753  0.078  0.653 -0.014  shoulder_press
#
# [40941 rows x 8 columns]

# %%
df_concatenated = pd.concat([completedf_front_raise, completedf_shoulder_press], ignore_index=True)

# %%
df_concatenated
# Out:
#             ax      ay      az     q0     q1     q2     q3           label
# 0       8272.0 -1434.0  1282.0  0.343 -0.629 -0.196 -0.669     front_raise
# 1       8712.0 -1518.0  1006.0  0.341 -0.630 -0.192 -0.670     front_raise
# 2       9318.0 -1464.0  1060.0  0.339 -0.632 -0.187 -0.671     front_raise
# 3       9922.0 -1780.0  1040.0  0.338 -0.634 -0.182 -0.672     front_raise
# 4      10366.0 -1970.0   850.0  0.338 -0.635 -0.176 -0.672     front_raise
# ...        ...     ...     ...    ...    ...    ...    ...             ...
# 83727  -9661.0 -1312.0 -2406.0  0.714 -0.015  0.699  0.030  shoulder_press
# 83728 -10159.0 -2438.0 -1764.0  0.725  0.005  0.689  0.021  shoulder_press
# 83729  -8901.0 -2868.0 -2208.0  0.736  0.029  0.677  0.010  shoulder_press
# 83730  -7483.0 -1260.0 -3020.0  0.746  0.054  0.664 -0.004  shoulder_press
# 83731  -6339.0  2196.0 -2828.0  0.753  0.078  0.653 -0.014  shoulder_press
#
# [83732 rows x 8 columns]

# %%
def split_sequences(dataframe, sequence_length):
    """Split the dataframe into sequences of a given length, including all relevant columns."""
    X, y = [], []
    columns_of_interest = ['q0', 'q1', 'q2', 'q3']
    for i in range(0, len(dataframe) - sequence_length + 1, sequence_length):
        sequence = dataframe.iloc[i:i+sequence_length][columns_of_interest]
        label = dataframe.iloc[i]['label']
        X.append(sequence.values)
        y.append(label)
    return np.array(X), np.array(y)

# %%
x, y = split_sequences(df_concatenated, 500)

# %%
len(x)
# Out:
# 167

# %%
len(y)
# Out:
# 167

# %%
len(x[0])
# Out:
# 500

# %%
y[1]
# Out:
# 'front_raise'

# %%
x.shape
# Out:
# (167, 500, 4)

# %% [markdown]
# ### Model Train

# %%
X_train_val, X_val, y_train_val, y_val = train_test_split(x, y, test_size=0.1)
X_train, X_test, y_train, y_test = train_test_split(X_train_val, y_train_val, test_size=0.1)

# %%
len(np.unique(y_train))
# Out:
# 2

# %%
y_train.shape, X_train.shape
# Out:
# ((135,), (135, 500, 4))

# %%
class_names = np.unique(y_train)
num_classes = len(np.unique(y_train))
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Convert text labels into numeric identifiers
y_train_encoded = label_encoder.fit_transform(y_train)

# Convert numeric labels into one-hot
y_train_one_hot = to_categorical(y_train_encoded)


# Convert text labels into numeric identifiers
y_val_encoded = label_encoder.fit_transform(y_val)


# Convert numeric labels into one-hot
y_val_one_hot = to_categorical(y_val_encoded)

# Convert text labels into numeric identifiers
y_test_encoded = label_encoder.fit_transform(y_test)

# Convert numeric labels into one-hot
y_test_one_hot = to_categorical(y_test_encoded)

# %%
# Define the model
inputs = tf.keras.Input(shape=(500, 4))

# Apply Dense layers to the inputs
layer = keras.layers.Dense(128, activation=tf.nn.relu6)(inputs)
layer = keras.layers.Dropout(0.5)(layer)
layer = keras.layers.Dense(64, activation=tf.nn.relu6)(layer)
layer = keras.layers.Dropout(0.5)(layer)

# Add GlobalAveragePooling1D to reduce dimensionality
layer = keras.layers.GlobalAveragePooling1D()(layer)

# Final layer for classification
outputs = keras.layers.Dense(len(np.unique(y_train)), activation="softmax")(layer)

model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 500, 4)]          0
#
#  dense_12 (Dense)            (None, 500, 128)          640
#
#  dropout_8 (Dropout)         (None, 500, 128)          0
#
#  dense_13 (Dense)            (None, 500, 64)           8256
#
#  dropout_9 (Dropout)         (None, 500, 64)           0
#
#  global_average_pooling1d_4   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  dense_14 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 9,026
# Trainable params: 9,026
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy', 
                                              patience=50)

# Start training
print(X_train.shape)
history = model.fit(X_train, y_train_one_hot,
                    epochs=200,
                    batch_size=16,
                    validation_data=(X_val, y_val_one_hot),
                    callbacks=[checkpoint, earlystopping],
                    )# class_weight=class_weights
# Out:
# (135, 500, 4)
# Epoch 1/200
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6644 - accuracy: 0.6562
# Epoch 1: val_accuracy improved from -inf to 0.82353, saving model to weights.best.hdf5
# 9/9 [==============================] - 1s 24ms/step - loss: 0.6623 - accuracy: 0.6667 - val_loss: 0.6054 - val_accuracy: 0.8235
# Epoch 2/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.5658 - accuracy: 0.9018
# Epoch 2: val_accuracy did not improve from 0.82353
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5584 - accuracy: 0.9185 - val_loss: 0.5172 - val_accuracy: 0.8235
# Epoch 3/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.4608 - accuracy: 0.9107
# Epoch 3: val_accuracy did not improve from 0.82353
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4517 - accuracy: 0.9111 - val_loss: 0.4421 - val_accuracy: 0.8235
# Epoch 4/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.3631 - accuracy: 0.9018
# Epoch 4: val_accuracy did not improve from 0.82353
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3461 - accuracy: 0.9111 - val_loss: 0.3879 - val_accuracy: 0.8235
# Epoch 5/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.2567 - accuracy: 0.9286
# Epoch 5: val_accuracy did not improve from 0.82353
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2659 - accuracy: 0.9185 - val_loss: 0.3575 - val_accuracy: 0.8235
# Epoch 6/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.2080 - accuracy: 0.9286
# Epoch 6: val_accuracy did not improve from 0.82353
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2070 - accuracy: 0.9259 - val_loss: 0.2854 - val_accuracy: 0.8235
# Epoch 7/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.1611 - accuracy: 0.9286
# Epoch 7: val_accuracy did not improve from 0.82353
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1602 - accuracy: 0.9333 - val_loss: 0.2393 - val_accuracy: 0.8235
# Epoch 8/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.1255 - accuracy: 0.9643
# Epoch 8: val_accuracy did not improve from 0.82353
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1230 - accuracy: 0.9630 - val_loss: 0.2005 - val_accuracy: 0.8235
# Epoch 9/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.1015 - accuracy: 0.9732
# Epoch 9: val_accuracy improved from 0.82353 to 1.00000, saving model to weights.best.hdf5
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0975 - accuracy: 0.9704 - val_loss: 0.1643 - val_accuracy: 1.0000
# Epoch 10/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0776 - accuracy: 0.9821
# Epoch 10: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0763 - accuracy: 0.9852 - val_loss: 0.1414 - val_accuracy: 1.0000
# Epoch 11/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0543 - accuracy: 1.0000
# Epoch 11: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0595 - accuracy: 0.9926 - val_loss: 0.1201 - val_accuracy: 1.0000
# Epoch 12/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0574 - accuracy: 0.9911
# Epoch 12: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0526 - accuracy: 0.9926 - val_loss: 0.1058 - val_accuracy: 1.0000
# Epoch 13/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0425 - accuracy: 0.9911
# Epoch 13: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0438 - accuracy: 0.9926 - val_loss: 0.1003 - val_accuracy: 1.0000
# Epoch 14/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0342 - accuracy: 0.9911
# Epoch 14: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0376 - accuracy: 0.9926 - val_loss: 0.0895 - val_accuracy: 1.0000
# Epoch 15/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0340 - accuracy: 0.9911
# Epoch 15: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0325 - accuracy: 0.9926 - val_loss: 0.0824 - val_accuracy: 1.0000
# Epoch 16/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0353 - accuracy: 0.9911
# Epoch 16: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0310 - accuracy: 0.9926 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 17/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0334 - accuracy: 0.9911
# Epoch 17: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0289 - accuracy: 0.9926 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 18/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0274 - accuracy: 0.9911
# Epoch 18: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0247 - accuracy: 0.9926 - val_loss: 0.0709 - val_accuracy: 1.0000
# Epoch 19/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0289 - accuracy: 0.9911
# Epoch 19: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0269 - accuracy: 0.9926 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 20/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0216 - accuracy: 0.9911
# Epoch 20: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0218 - accuracy: 0.9926 - val_loss: 0.0671 - val_accuracy: 1.0000
# Epoch 21/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0309 - accuracy: 0.9911
# Epoch 21: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0268 - accuracy: 0.9926 - val_loss: 0.0692 - val_accuracy: 0.9412
# Epoch 22/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0235 - accuracy: 0.9911
# Epoch 22: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0205 - accuracy: 0.9926 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 23/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0242 - accuracy: 0.9911
# Epoch 23: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0205 - accuracy: 0.9926 - val_loss: 0.0607 - val_accuracy: 1.0000
# Epoch 24/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0182 - accuracy: 0.9911
# Epoch 24: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0192 - accuracy: 0.9926 - val_loss: 0.0576 - val_accuracy: 1.0000
# Epoch 25/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0240 - accuracy: 0.9911
# Epoch 25: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0207 - accuracy: 0.9926 - val_loss: 0.0641 - val_accuracy: 0.9412
# Epoch 26/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0217 - accuracy: 0.9911
# Epoch 26: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0197 - accuracy: 0.9926 - val_loss: 0.0551 - val_accuracy: 1.0000
# Epoch 27/200
# 6/9 [===================>..........] - ETA: 0s - loss: 0.0163 - accuracy: 0.9896
# Epoch 27: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0182 - accuracy: 0.9926 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 28/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0196 - accuracy: 0.9911
# Epoch 28: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0170 - accuracy: 0.9926 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 29/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0203 - accuracy: 0.9911
# Epoch 29: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0171 - accuracy: 0.9926 - val_loss: 0.0524 - val_accuracy: 1.0000
# Epoch 30/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0145 - accuracy: 0.9911
# Epoch 30: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0176 - accuracy: 0.9926 - val_loss: 0.0507 - val_accuracy: 1.0000
# Epoch 31/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0176 - accuracy: 0.9911
# Epoch 31: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0149 - accuracy: 0.9926 - val_loss: 0.0606 - val_accuracy: 0.9412
# Epoch 32/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0195 - accuracy: 0.9911
# Epoch 32: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0169 - accuracy: 0.9926 - val_loss: 0.0519 - val_accuracy: 1.0000
# Epoch 33/200
# 6/9 [===================>..........] - ETA: 0s - loss: 0.0171 - accuracy: 0.9896
# Epoch 33: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0177 - accuracy: 0.9926 - val_loss: 0.0475 - val_accuracy: 1.0000
# Epoch 34/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0111 - accuracy: 0.9911
# Epoch 34: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0138 - accuracy: 0.9926 - val_loss: 0.0475 - val_accuracy: 1.0000
# Epoch 35/200
# 6/9 [===================>..........] - ETA: 0s - loss: 0.0074 - accuracy: 1.0000
# Epoch 35: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0195 - accuracy: 0.9926 - val_loss: 0.0629 - val_accuracy: 0.9412
# Epoch 36/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0059 - accuracy: 1.0000
# Epoch 36: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0151 - accuracy: 0.9926 - val_loss: 0.0471 - val_accuracy: 1.0000
# Epoch 37/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0144 - accuracy: 0.9911
# Epoch 37: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0138 - accuracy: 0.9926 - val_loss: 0.0480 - val_accuracy: 1.0000
# Epoch 38/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0171 - accuracy: 1.0000
# Epoch 38: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 39/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0138 - accuracy: 0.9926 - val_loss: 0.0488 - val_accuracy: 1.0000
# Epoch 40/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 40: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0533 - val_accuracy: 1.0000
# Epoch 41/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0149 - accuracy: 1.0000
# Epoch 41: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 42/200
# 6/9 [===================>..........] - ETA: 0s - loss: 0.0148 - accuracy: 0.9896
# Epoch 42: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0115 - accuracy: 0.9926 - val_loss: 0.0472 - val_accuracy: 1.0000
# Epoch 43/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0141 - accuracy: 0.9911
# Epoch 43: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0119 - accuracy: 0.9926 - val_loss: 0.0436 - val_accuracy: 1.0000
# Epoch 44/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 1.0000
# Epoch 45/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0125 - accuracy: 0.9911
# Epoch 45: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0107 - accuracy: 0.9926 - val_loss: 0.0484 - val_accuracy: 1.0000
# Epoch 46/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0115 - accuracy: 0.9911
# Epoch 46: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0117 - accuracy: 0.9926 - val_loss: 0.0425 - val_accuracy: 1.0000
# Epoch 47/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0117 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 1.0000
# Epoch 48/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0093 - accuracy: 0.9911
# Epoch 48: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0105 - accuracy: 0.9926 - val_loss: 0.0444 - val_accuracy: 1.0000
# Epoch 49/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 49: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0095 - accuracy: 0.9926 - val_loss: 0.0436 - val_accuracy: 1.0000
# Epoch 50/200
# 6/9 [===================>..........] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 50: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 1.0000
# Epoch 51/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0090 - accuracy: 1.0000
# Epoch 51: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0396 - val_accuracy: 1.0000
# Epoch 52/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0095 - accuracy: 1.0000
# Epoch 52: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 53/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 53: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0097 - accuracy: 0.9926 - val_loss: 0.0495 - val_accuracy: 0.9412
# Epoch 54/200
# 6/9 [===================>..........] - ETA: 0s - loss: 0.0120 - accuracy: 0.9896
# Epoch 54: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0104 - accuracy: 0.9926 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 55/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 55: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0392 - val_accuracy: 1.0000
# Epoch 56/200
# 6/9 [===================>..........] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 56: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0414 - val_accuracy: 1.0000
# Epoch 57/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 57: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 58/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 1.0000
# Epoch 59/200
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0089 - accuracy: 1.0000
# Epoch 59: val_accuracy did not improve from 1.00000
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0405 - val_accuracy: 1.0000

# %%
# Visualize the training history to see whether you're overfitting.
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')
plt.grid()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test_one_hot)
# Out:
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0092 - accuracy: 1.0000

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """Plots the confusion matrix."""
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=55)
  plt.yticks(tick_marks, classes)
  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
              horizontalalignment="center",
              color="white" if cm[i, j] > thresh else "black")

  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.tight_layout()

# Classify pose in the TEST dataset using the trained model
y_pred = model.predict(X_test)

# Convert the prediction result to class name
y_pred_label = [class_names[i] for i in np.argmax(y_pred, axis=1)]
y_true_label = [class_names[i] for i in np.argmax(y_test_one_hot, axis=1)]

# Plot the confusion matrix
cm = confusion_matrix(np.argmax(y_test_one_hot, axis=1), np.argmax(y_pred, axis=1))
plot_confusion_matrix(cm,
                      class_names,
                      title ='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label, y_pred_label))
# Out:
# 1/1 [==============================] - 0s 71ms/step
# Confusion matrix, without normalization
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#    front_raise       1.00      1.00      1.00         5
# shoulder_press       1.00      1.00      1.00        10
#
#       accuracy                           1.00        15
#      macro avg       1.00      1.00      1.00        15
#   weighted avg       1.00      1.00      1.00        15
